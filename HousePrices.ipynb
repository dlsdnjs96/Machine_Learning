# %%
import numpy as np
import pandas as pd
import seaborn as sb

from sklearn.preprocessing import LabelEncoder, StandardScaler, RobustScaler, MinMaxScaler

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_seq_items', None)

# %%
train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/HousePrices/train.csv')
test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/HousePrices/test.csv')
submission = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/HousePrices/sample_submission.csv')

# %%
all_data = pd.concat([train, test], sort=False)
#all_data = train

# %%
all_data['MSZoning(status)'] = 0
all_data.loc[all_data['MSZoning'] == 'A', 'MSZoning(status)'] = 1
all_data.loc[all_data['MSZoning'] == 'C', 'MSZoning(status)'] = 2
all_data.loc[all_data['MSZoning'] == 'FV', 'MSZoning(status)'] = 3
all_data.loc[all_data['MSZoning'] == 'I', 'MSZoning(status)'] = 4
all_data.loc[all_data['MSZoning'] == 'RH', 'MSZoning(status)'] = 5
all_data.loc[all_data['MSZoning'] == 'RL', 'MSZoning(status)'] = 6
all_data.loc[all_data['MSZoning'] == 'RP', 'MSZoning(status)'] = 7
all_data.loc[all_data['MSZoning'] == 'RM', 'MSZoning(status)'] = 8

# %%
all_data = all_data.drop('MSZoning', axis=1)

# %%
rating_col = ['ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'HeatingQC', 'KitchenQual', 'FireplaceQu', 'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence']

########################################################################

col = 'ExterQual'
ratings = ['Ex', 'Gd', 'TA', 'Fa', 'Po']
score = len(ratings)
all_data[col+'(status)'] = 0
for i in ratings:
  all_data.loc[all_data[col] == i, col+'(status)'] = score
  score -= 1

########################################################################

col = 'ExterCond'
ratings = ['Ex', 'Gd', 'TA', 'Fa', 'Po']
score = len(ratings)
all_data[col+'(status)'] = 0
for i in ratings:
  all_data.loc[all_data[col] == i, col+'(status)'] = score
  score -= 1

########################################################################

col = 'BsmtQual'
ratings = ['Ex', 'Gd', 'TA', 'Fa', 'Po']
score = len(ratings)
all_data[col+'(status)'] = 0
for i in ratings:
  all_data.loc[all_data[col] == i, col+'(status)'] = score
  score -= 1

########################################################################

col = 'BsmtCond'
ratings = ['Ex', 'Gd', 'TA', 'Fa', 'Po']
score = len(ratings)
all_data[col+'(status)'] = 0
for i in ratings:
  all_data.loc[all_data[col] == i, col+'(status)'] = score
  score -= 1

########################################################################

col = 'BsmtExposure'
ratings = ['Gd', 'Av', 'Mn', 'No']
score = len(ratings)
all_data[col+'(status)'] = 0
for i in ratings:
  all_data.loc[all_data[col] == i, col+'(status)'] = score
  score -= 1

########################################################################

col = 'BsmtFinType1'
ratings = ['GLQ', 'ALQ', 'BLQ', 'Rec', 'LwQ', 'Unf']
score = len(ratings)
all_data[col+'(status)'] = 0
for i in ratings:
  all_data.loc[all_data[col] == i, col+'(status)'] = score
  score -= 1

########################################################################

col = 'BsmtFinType2'
ratings = ['GLQ', 'ALQ', 'BLQ', 'Rec', 'LwQ', 'Unf']
score = len(ratings)
all_data[col+'(status)'] = 0
for i in ratings:
  all_data.loc[all_data[col] == i, col+'(status)'] = score
  score -= 1

########################################################################

col = 'HeatingQC'
ratings = ['Ex', 'Gd', 'TA', 'Fa', 'Po']
score = len(ratings)
all_data[col+'(status)'] = 0
for i in ratings:
  all_data.loc[all_data[col] == i, col+'(status)'] = score
  score -= 1

########################################################################

col = 'KitchenQual'
ratings = ['Ex', 'Gd', 'TA', 'Fa', 'Po']
score = len(ratings)
all_data[col+'(status)'] = 0
for i in ratings:
  all_data.loc[all_data[col] == i, col+'(status)'] = score
  score -= 1

########################################################################

col = 'FireplaceQu'
ratings = ['Ex', 'Gd', 'TA', 'Fa', 'Po']
score = len(ratings)
all_data[col+'(status)'] = 0
for i in ratings:
  all_data.loc[all_data[col] == i, col+'(status)'] = score
  score -= 1

########################################################################

col = 'GarageFinish'
ratings = ['Fin', 'RFn', 'Unf']
score = len(ratings)
all_data[col+'(status)'] = 0
for i in ratings:
  all_data.loc[all_data[col] == i, col+'(status)'] = score
  score -= 1

########################################################################

col = 'GarageQual'
ratings = ['Ex', 'Gd', 'TA', 'Fa', 'Po']
score = len(ratings)
all_data[col+'(status)'] = 0
for i in ratings:
  all_data.loc[all_data[col] == i, col+'(status)'] = score
  score -= 1

########################################################################

col = 'GarageCond'
ratings = ['Ex', 'Gd', 'TA', 'Fa', 'Po']
score = len(ratings)
all_data[col+'(status)'] = 0
for i in ratings:
  all_data.loc[all_data[col] == i, col+'(status)'] = score
  score -= 1

########################################################################

col = 'PoolQC'
ratings = ['Ex', 'Gd', 'TA', 'Fa']
score = len(ratings)
all_data[col+'(status)'] = 0
for i in ratings:
  all_data.loc[all_data[col] == i, col+'(status)'] = score
  score -= 1

########################################################################

col = 'Fence'
ratings = ['DgPrv', 'MnPrv', 'GdWo', 'MnWw']
score = len(ratings)
all_data[col+'(status)'] = 0
for i in ratings:
  all_data.loc[all_data[col] == i, col+'(status)'] = score
  score -= 1

########################################################################

col = 'LotShape'
ratings = ['Reg', 'IR1', 'IR2', 'IR3']
score = len(ratings)
all_data[col+'(status)'] = 0
for i in ratings:
  all_data.loc[all_data[col] == i, col+'(status)'] = score
  score -= 1

########################################################################

col = 'Utilities'
ratings = ['AllPub', 'NoSewr', 'NoSeWa', 'ELO']
score = len(ratings)
all_data[col+'(status)'] = 0
for i in ratings:
  all_data.loc[all_data[col] == i, col+'(status)'] = score
  score -= 1

all_data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  2919.000000  2919.000000  2433.000000    2919.000000  2919.000000
# mean   1460.000000    57.137718    69.305795   10168.114080     6.089072
# std     842.787043    42.517628    23.344905    7886.996359     1.409947
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     730.500000    20.000000    59.000000    7478.000000     5.000000
# 50%    1460.000000    50.000000    68.000000    9453.000000     6.000000
# 75%    2189.500000    70.000000    80.000000   11570.000000     7.000000
# max    2919.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  2919.000000  2919.000000   2919.000000  2896.000000  2918.000000
# mean      5.564577  1971.312778   1984.264474   102.201312   441.423235
# std       1.113131    30.291442     20.894344   179.334253   455.610826
# ...

# %%
rating_col = ['ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'HeatingQC', 'KitchenQual', 'FireplaceQu', 'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence']

for i in rating_col:
  all_data = all_data.drop(i, axis=1)

# %%
all_data['Street(status)'] = False
all_data.loc[all_data['Street'] == 'Grvl', 'Street(status)'] = True
all_data = all_data.drop('Street', axis=1)

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
cols = ['RoofMatl', 'Exterior1st', 'RoofStyle', 'HouseStyle', 'Condition1', 'Condition2', 'Neighborhood', 'MasVnrType', 'Foundation', 
        'Exterior2nd', 'GarageType', 'MiscFeature', 'SaleType', 'SaleCondition', 'Electrical', 'Heating', 'BldgType', 'LandSlope', 
        'LotConfig', 'LandContour', 'Alley', 'LotShape', 'Utilities']

for i in cols:
  materials = all_data[i].unique()

  #print('\r\n\r\n##### '+i+' #####')

  mList = [[0 for rows in range(len(materials))] for cols in range(2)]
  mean = 0
  cnt = 0

  for j in materials:
    sum = train.loc[train[i] == j, 'SalePrice'].sum()
    count = train.loc[train[i] == j, 'SalePrice'].count()

    if count > 0:
      ave = round(sum/count)
      mean += ave
      cnt += 1

  mean /= cnt
  all_data[i+'(status)'] = mean

  cnt = 0

  for j in materials:
    sum = train.loc[train[i] == j, 'SalePrice'].sum()
    count = train.loc[train[i] == j, 'SalePrice'].count()

    if count > 0:
      #print(j+' : '+(str)(sum)+' '+(str)(count)+'')

      ave = round(sum/count)
      

      mList[0][cnt] = j
      mList[1][cnt] = ave
      cnt += 1
      all_data.loc[all_data[i] == j, i+'(status)'] = ave

# %%
cols_s = ['LotShape(status)', 'Utilities(status)', 'RoofMatl(status)', 'Exterior1st(status)',
       'RoofStyle(status)', 'HouseStyle(status)', 'Condition1(status)',
       'Condition2(status)', 'Neighborhood(status)', 'MasVnrType(status)',
       'Foundation(status)', 'Exterior2nd(status)', 'GarageType(status)',
       'MiscFeature(status)', 'SaleType(status)', 'SaleCondition(status)',
       'Electrical(status)', 'Heating(status)', 'BldgType(status)',
       'LandSlope(status)', 'LotConfig(status)', 'LandContour(status)',
       'Alley(status)']


#print(all_data[cols_s].describe())

for i in cols_s:
  ave = all_data.loc[all_data[i] > 0, i].mean()
  #print(ave)
  all_data.loc[all_data[i] == 0, i] = ave


scaler = StandardScaler()#RobustScaler()
scaeld_all_data = all_data[cols_s]

scaler.fit(scaeld_all_data)
scaeld_all_data = scaler.transform(scaeld_all_data)
scaeld_all_data = pd.DataFrame(scaeld_all_data, columns=cols_s)
scaeld_all_data.describe()
#all_data[cols_s].describe()
# Out:
#        LotShape(status)  Utilities(status)  RoofMatl(status)  \
# count      2.919000e+03       2.919000e+03      2.919000e+03
# mean      -4.841774e-16      -2.173217e-15      8.036661e-17
# std        1.000171e+00       1.000171e+00      1.000171e+00
# min       -7.326521e-01      -5.401851e+01     -3.980324e+00
# 25%       -7.326521e-01       1.852487e-02     -6.750604e-02
# 50%       -7.326521e-01       1.852487e-02     -6.750604e-02
# 75%        1.166909e+00       1.852487e-02     -6.750604e-02
# max        2.716576e+00       1.852487e-02      1.916988e+01
#
#        Exterior1st(status)  RoofStyle(status)  HouseStyle(status)  \
# count         2.918000e+03       2.919000e+03        2.919000e+03
# mean          6.719170e-17       2.630076e-16        3.506768e-16
# std           1.000171e+00       1.000171e+00        1.000171e+00
# min          -3.502984e+00      -1.679931e+00       -3.061666e+00
# 25%          -9.813371e-01      -4.811492e-01       -2.003548e-01
# ...

# %%
for i in cols:
  all_data = all_data.drop(i, axis=1)

# %%
all_data['remodeled'] = False
all_data.loc[all_data['YearBuilt'] == all_data['YearRemodAdd'], 'remodeled'] = True

all_data['CentralAir(status)'] = all_data['CentralAir'] == 'Y'

# %%
for i in all_data.columns:
  n1 = all_data[i].isnull().sum()
  n2 = all_data[i].count()

  if n1 > 0:
    print(i+' : '+(str)(round(100 * n1 / n2, 2))+'%')
# Out:
# LotFrontage : 21.57%
# Alley : 1504.4%
# MasVnrType : 0.55%
# MasVnrArea : 0.55%
# Electrical : 0.07%
# GarageType : 5.87%
# GarageYrBlt : 5.87%
# MiscFeature : 2603.7%

# %%
all_data.corr()
# Out:
#                              Id  MSSubClass  LotFrontage   LotArea  \
# Id                     1.000000    0.008931    -0.027549 -0.040746
# MSSubClass             0.008931    1.000000    -0.417359 -0.201730
# LotFrontage           -0.027549   -0.417359     1.000000  0.489896
# LotArea               -0.040746   -0.201730     0.489896  1.000000
# OverallQual           -0.029771    0.033638     0.217645  0.100541
# OverallCond           -0.002839   -0.065625    -0.075508 -0.035617
# YearBuilt             -0.016581    0.034409     0.122811  0.024128
# YearRemodAdd          -0.050438    0.043315     0.091557  0.021612
# MasVnrArea            -0.025219    0.005433     0.221079  0.125596
# BsmtFinSF1            -0.016947   -0.064311     0.219408  0.194031
# BsmtFinSF2             0.018251   -0.072530     0.047431  0.084059
# BsmtUnfSF             -0.014453   -0.125994     0.113714  0.021362
# TotalBsmtSF           -0.024924   -0.219965     0.354822  0.254138
# ...

# %%
nTrain = len(train)
train = all_data[:nTrain]
test = all_data[nTrain:]

# %%
x_col = ['MSZoning(status)', 'ExterQual(status)', 'ExterCond(status)',
       'BsmtQual(status)', 'BsmtCond(status)', 'BsmtExposure(status)',
       'BsmtFinType1(status)', 'BsmtFinType2(status)', 'HeatingQC(status)',
       'KitchenQual(status)', 'FireplaceQu(status)', 'GarageFinish(status)',
       'GarageQual(status)', 'GarageCond(status)', 'PoolQC(status)',
       'Fence(status)', 'LotShape(status)', 'Utilities(status)',
       'Street(status)', 'RoofMatl(status)', 'Exterior1st(status)',
       'RoofStyle(status)', 'HouseStyle(status)', 'Condition1(status)',
       'Condition2(status)', 'Neighborhood(status)', 'MasVnrType(status)',
       'Foundation(status)', 'Exterior2nd(status)', 'GarageType(status)',
       'MiscFeature(status)', 'SaleType(status)', 'SaleCondition(status)',
       'Electrical(status)', 'Heating(status)', 'BldgType(status)',
       'LandSlope(status)', 'LotConfig(status)', 'LandContour(status)',
       'Alley(status)', 'remodeled', 'CentralAir(status)', 'Fireplaces', 
       'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd']
y_col = 'SalePrice'

# %%
x_train = train[x_col]
y_train = train[y_col]

x_test = test[x_col]

x_train.describe()
# Out:
#        MSZoning(status)  ExterQual(status)  ExterCond(status)  \
# count       1460.000000         1460.00000        1460.000000
# mean           6.113014            3.39589           3.083562
# std            1.115150            0.57428           0.351054
# min            0.000000            2.00000           1.000000
# 25%            6.000000            3.00000           3.000000
# 50%            6.000000            3.00000           3.000000
# 75%            6.000000            4.00000           3.000000
# max            8.000000            5.00000           5.000000
#
#        BsmtQual(status)  BsmtCond(status)  BsmtExposure(status)  \
# count       1460.000000       1460.000000           1460.000000
# mean           3.489041          2.934932              1.630137
# std            0.876478          0.552159              1.067391
# min            0.000000          0.000000              0.000000
# 25%            3.000000          3.000000              1.000000
# ...

# %%
from xgboost import XGBRegressor
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.linear_model import LinearRegression

from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import mean_squared_error

# %%
xgb = XGBRegressor(random_state=37)
gbr = GradientBoostingRegressor(random_state=37)
rfr = RandomForestRegressor(random_state=37)

rfc = RandomForestClassifier(random_state=37)
dtc = DecisionTreeClassifier(random_state=37)


models = [xgb, gbr, rfr, rfc, dtc]
names = ['XGBRegressor', 'GradientBoostingRegressor', 'RandomForestRegressor', 'RandomForestClassifier', 'DecisionTreeClassifier']


for md, nm in zip(models, names):
  md.fit(x_train, y_train)
  pred = md.predict(x_test)

  leng = len(y_train)
  if leng > len(pred):
    leng = len(pred)

  print(nm+" : "+(str)(mean_squared_error(y_train[:leng], pred[:leng], squared=False))+"\r\n")
# Out:
# [08:45:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor : 108985.23370242272
#
# GradientBoostingRegressor : 109068.54886117986
#
# RandomForestRegressor : 107483.5342007043
#
# RandomForestClassifier : 106726.41218962197
#
# DecisionTreeClassifier : 114612.53342774147

# %%
rfc.fit(x_train, y_train)
pred = rfc.predict(x_test)

# %%
submission[y_col] = pred
submission.to_csv('/content/drive/MyDrive/Colab Notebooks/HousePrices/submission.csv', index=False)
